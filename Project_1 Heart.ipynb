# %% [markdown]
# # Heart Attack Prediction Metrics

# %% [markdown]
# This project focuses on the factors that predict heart attacks in adults. To determine the factors that predict heart attacks in adults several data sets were utilized and cleaned in this project, and referenced below.

# %% [markdown]
# #### Part one : Importing and Merging/ joing Data

# %%
import pandas as pd
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

# %%
#import data 
data_1 = 'project_1 data/framingham.csv'
data_2 = 'project_1 data/heart_2020_cleaned.csv'

#read in data
fram_df = pd.read_csv(data_1)
heart_df = pd.read_csv(data_2)

# %% [markdown]
# # Data_1 Here we will organize, clean and explore our first dataset, Mohamed will take lead on this. Our First dataset will be the Framingham data.

# %%
#diplay sample dataframes, inspect the data
display(fram_df.head())
display(fram_df.tail())
display(fram_df.info())
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %% [markdown]
# # data_2 Here we will explore and clean our second data set. Mohamed will lead this section. this set of data will cover the CDC's dataset

# %%
# inspect the data
display(heart_df.head())
display(heart_df.tail())
display(heart_df.info())
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %% [markdown]
# # Merged Data sets. in this area we will begin to explore merging our data together. Jeff is taking lead on this section.

# %% [markdown]
# # What is the most important factor in determining heart disease?

# %% [markdown]
# # What are the highest coorelated factors for heart disease?

# %% [markdown]
# # What groups are the most at risk for heart attacks?

# %% [markdown]
# # What could be the most important choices made to reverse the potential negative outcoes of heart disease?

# %% [markdown]
# # How will this data help hospitals to make informed decisions and develop effective business plans and strategies?

# %% [markdown]
# # Prophet predictions. this will be our experimental area for trying to predict coronary outcomes based on ages... this will take us some time to work out.

# %%
# convert the ages to datetime

# %%
# figure out the y value for the prophet modeling
